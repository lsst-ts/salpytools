# %%
from salpytools import salpylib

# %%
a = salpylib.DDSSend("scheduler")
# Out:
# [2018-06-19 13:03:37] [INFO] Loading Device: scheduler
# [2018-06-19 13:03:37] [INFO] importing SALPY_scheduler

# %%
a
# Out:
# <DDSSend(Thread-4, initial daemon)>

# %%
cmd_id = a.send_Command('enterControl')
# Out:
# [2018-06-19 13:03:59] [INFO] Updating myData object with kwargs
# [2018-06-19 13:03:59] [INFO] Issuing command: enterControl
# [2018-06-19 13:03:59] [INFO] Will NOT wait Command Completion

# %%
a.send_Command('start')
# Out:
# [2018-06-19 13:04:16] [INFO] Updating myData object with kwargs
# [2018-06-19 13:04:16] [INFO] Issuing command: start
# [2018-06-19 13:04:16] [INFO] Will NOT wait Command Completion
# 1189641421

# %%
a.send_Command('enable')
# Out:
# [2018-06-19 13:04:31] [INFO] Updating myData object with kwargs
# [2018-06-19 13:04:31] [INFO] Issuing command: enable
# [2018-06-19 13:04:31] [INFO] Will NOT wait Command Completion
# 1025202362

# %%
a.send_Command('disable')
# Out:
# [2018-06-19 13:04:41] [INFO] Updating myData object with kwargs
# [2018-06-19 13:04:41] [INFO] Issuing command: disable
# [2018-06-19 13:04:41] [INFO] Will NOT wait Command Completion
# 1350490027

# %%
a.send_Command('standby')
# Out:
# [2018-06-19 13:04:51] [INFO] Updating myData object with kwargs
# [2018-06-19 13:04:51] [INFO] Issuing command: standby
# [2018-06-19 13:04:51] [INFO] Will NOT wait Command Completion
# 783368690

# %%
a.send_Command('exitControl')
# Out:
# [2018-06-19 13:04:58] [INFO] Updating myData object with kwargs
# [2018-06-19 13:04:58] [INFO] Issuing command: exitControl
# [2018-06-19 13:04:58] [INFO] Will NOT wait Command Completion
# 1102520059
