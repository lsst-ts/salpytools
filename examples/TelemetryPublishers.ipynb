# %%
from salpytools import salpylib
from SALPY_scheduler import *

# %%
#Bulk Cloud publish topic
mgr = SAL_scheduler()
mgr.salTelemetryPub("scheduler_bulkCloud")
myData = scheduler_bulkCloudC()
myData.bulkCloud = 300.0
myData.timestamp = 1.0

mgr.putSample_bulkCloud(myData)

# %%
#Seeing publish topic
mgr = SAL_scheduler()
mgr.salTelemetryPub("scheduler_seeing")
myData = scheduler_seeingC()
myData.seeing = 1.0
myData.timestamp = 1.0

mgr.putSample_seeing(myData)
