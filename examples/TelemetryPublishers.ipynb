# %%
from lsst.salpytools import salpylib
import SALPY_scheduler

# %%
#Bulk Cloud publish topic
mgr = SAL_scheduler()
mgr.salTelemetryPub("scheduler_bulkCloud")
myData = SALPY_scheduler.scheduler_bulkCloudC()
myData.bulk_cloud = 375.0
myData.timestamp = 3.0

mgr.putSample_bulkCloud(myData)

# %%
#invalidateTarget publish topic
mgr = SAL_scheduler()
mgr.salEvent("scheduler_logevent_invalidateTarget")
myData = SALPY_scheduler.scheduler_logevent_invalidateTargetC()
myData.target_id=4
myData.invalid=1
myData.timestamp=6.0
myData.priority=3
priority=int(myData.priority)

mgr.logEvent_invalidateTarget(myData, priority)
